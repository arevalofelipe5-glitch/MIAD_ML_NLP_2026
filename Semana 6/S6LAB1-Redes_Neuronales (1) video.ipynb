# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Redes Neuronales
#
# En este notebook aprenderá a construir y a entrenar redes neuronales de una capa y multicapas, usando la librería [Keras](https://keras.io/).
#
# Este notebook tiene una licencia de [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). Un agradecimiento especial para [Valerio Maggio](https://mpba.fbk.eu).

# %% [markdown]
# ## Instrucciones Generales
#
# Keras es una librería de redes neuronales altamente modular, escrita en Python y capaz de ejecutarse sobre TensorFlow o Theano. Fue desarrollada con el objetivo de permitir una experimentación rápida con modelos de redes neuronales.
#
# Este notebook esta compuesto por dos secciones. En la primera sección, usted beberá construir y entrenar una red neuronal de una capa para predecir el precio de una casa con el set de datos Boston Housing Data. En la segunda parte, se usará el mismo dataset pero usted beberá construir y entrenar una red neuronal multicapa para identificar sus ventajas. Para conocer más detalles de la base, puede ingresar al siguiente [vínculo](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/).
#
# Para realizar la actividad, solo siga las indicaciones asociadas a cada celda del notebook.

# %% [markdown]
# ## Importar base de datos y librerías

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import pandas as pd
from sklearn.datasets import load_boston
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_boston
# Carga de datos de la librería sklearn
boston_dataset = load_boston()
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ## Definición de variables predictoras  y de interés

# %%
# Definición de variables predictoras (X)
X = boston.drop(boston.columns[-1],axis=1)
# Definición de variable de interés (y)
Y = pd.DataFrame(np.array(boston_dataset.target), columns=['labels'])

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
X_train, X_test , Y_train, Y_test = train_test_split(X,Y, test_size=0.3 ,random_state=22)

# %%
# Normalización de variables predictoras (X) con la función StandardScaler
from sklearn.preprocessing import StandardScaler

# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
# Definición de dimensiones de salida, varaibles de interés
output_var = Y_train.shape[1]
print(output_var, ' output variables')
# Out:
# 1  output variables

# %%
# Definición de dimensiones de entrada, varaibles predictoras
dims = X_train.shape[1]
print(dims, 'input variables')
# Out:
# 12 input variables

# %% [markdown]
# # Red neuronal de una sola capa

# %%
# Importación librerías
from keras.models import Sequential
from keras.layers import Dense, Activation
from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 13
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train, 
          verbose=1, 
          epochs=50, 
          validation_data=(X_test, Y_test),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:   28.061, max:  476.989, cur:   28.061)
# 	validation       	 (min:   25.319, max:  389.635, cur:   25.548)
# 12/12 [==============================] - 0s 19ms/step - loss: 28.0609 - val_loss: 25.5483

# %% [markdown]
# ## Red neuronal de una sola capa con early stopping

# %%
# Importación librerías
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 13
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# %%
# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model.h5'
best_model = ModelCheckpoint(fBestModel, verbose=0, save_best_only=True)

# %%
# Entrenamiento de la red neuronal con 50 épocas y early stopping
model.fit(X_train, Y_train, 
          verbose=True, 
          epochs=50, 
          batch_size=128,
          validation_data=(X_test,Y_test),
          callbacks=[best_model, early_stop])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 65ms/step - loss: 562.9795 - val_loss: 540.6106
# Epoch 2/50
# 3/3 [==============================] - 0s 28ms/step - loss: 490.7736 - val_loss: 476.7544
# Epoch 3/50
# 3/3 [==============================] - 0s 27ms/step - loss: 433.6055 - val_loss: 423.3916
# Epoch 4/50
# 3/3 [==============================] - 0s 27ms/step - loss: 384.6684 - val_loss: 378.1321
# Epoch 5/50
# 3/3 [==============================] - 0s 28ms/step - loss: 344.0493 - val_loss: 338.8189
# Epoch 6/50
# 3/3 [==============================] - 0s 28ms/step - loss: 308.3523 - val_loss: 304.1162
# Epoch 7/50
# 3/3 [==============================] - 0s 30ms/step - loss: 277.0109 - val_loss: 273.4825
# Epoch 8/50
# 3/3 [==============================] - 0s 29ms/step - loss: 249.1916 - val_loss: 246.2046
# Epoch 9/50
# 3/3 [==============================] - 0s 28ms/step - loss: 225.0499 - val_loss: 222.5029
# Epoch 10/50
# 3/3 [==============================] - 0s 26ms/step - loss: 203.2735 - val_loss: 201.1510
# Epoch 11/50
# 3/3 [==============================] - 0s 28ms/step - loss: 184.0298 - val_loss: 181.8836
# Epoch 12/50
# 3/3 [==============================] - 0s 29ms/step - loss: 166.9422 - val_loss: 164.9418
# Epoch 13/50
# 3/3 [==============================] - 0s 27ms/step - loss: 151.8357 - val_loss: 149.7245
# Epoch 14/50
# 3/3 [==============================] - 0s 30ms/step - loss: 138.3814 - val_loss: 136.1302
# Epoch 15/50
# 3/3 [==============================] - 0s 30ms/step - loss: 126.4144 - val_loss: 124.2602
# Epoch 16/50
# 3/3 [==============================] - 0s 33ms/step - loss: 115.6175 - val_loss: 113.7047
# Epoch 17/50
# 3/3 [==============================] - 0s 29ms/step - loss: 106.0379 - val_loss: 104.2303
# Epoch 18/50
# 3/3 [==============================] - 0s 29ms/step - loss: 97.8580 - val_loss: 95.8860
# Epoch 19/50
# 3/3 [==============================] - 0s 28ms/step - loss: 90.3717 - val_loss: 88.3824
# Epoch 20/50
# 3/3 [==============================] - 0s 28ms/step - loss: 83.7294 - val_loss: 81.6613
# Epoch 21/50
# 3/3 [==============================] - 0s 33ms/step - loss: 77.8845 - val_loss: 75.6581
# Epoch 22/50
# 3/3 [==============================] - 0s 28ms/step - loss: 72.6432 - val_loss: 70.3102
# Epoch 23/50
# 3/3 [==============================] - 0s 28ms/step - loss: 67.6884 - val_loss: 65.5240
# Epoch 24/50
# 3/3 [==============================] - 0s 29ms/step - loss: 63.5329 - val_loss: 61.2291
# Epoch 25/50
# 3/3 [==============================] - 0s 30ms/step - loss: 59.9484 - val_loss: 57.2878
# Epoch 26/50
# 3/3 [==============================] - 0s 28ms/step - loss: 56.4471 - val_loss: 54.0173
# Epoch 27/50
# 3/3 [==============================] - 0s 27ms/step - loss: 53.5258 - val_loss: 50.9859
# Epoch 28/50
# 3/3 [==============================] - 0s 29ms/step - loss: 50.9495 - val_loss: 48.2835
# Epoch 29/50
# 3/3 [==============================] - 0s 28ms/step - loss: 48.6101 - val_loss: 45.9215
# Epoch 30/50
# 3/3 [==============================] - 0s 28ms/step - loss: 46.4820 - val_loss: 43.8385
# Epoch 31/50
# 3/3 [==============================] - 0s 27ms/step - loss: 44.6167 - val_loss: 41.9794
# Epoch 32/50
# 3/3 [==============================] - 0s 27ms/step - loss: 42.9863 - val_loss: 40.3182
# Epoch 33/50
# 3/3 [==============================] - 0s 28ms/step - loss: 41.4509 - val_loss: 38.8468
# Epoch 34/50
# 3/3 [==============================] - 0s 32ms/step - loss: 40.1971 - val_loss: 37.5773
# Epoch 35/50
# 3/3 [==============================] - 0s 27ms/step - loss: 38.9397 - val_loss: 36.3790
# Epoch 36/50
# 3/3 [==============================] - 0s 28ms/step - loss: 37.8785 - val_loss: 35.3273
# Epoch 37/50
# 3/3 [==============================] - 0s 27ms/step - loss: 37.0049 - val_loss: 34.3368
# Epoch 38/50
# 3/3 [==============================] - 0s 27ms/step - loss: 36.0690 - val_loss: 33.5024
# Epoch 39/50
# 3/3 [==============================] - 0s 28ms/step - loss: 35.3174 - val_loss: 32.7485
# Epoch 40/50
# 3/3 [==============================] - 0s 29ms/step - loss: 34.6930 - val_loss: 32.1175
# Epoch 41/50
# 3/3 [==============================] - 0s 28ms/step - loss: 34.1199 - val_loss: 31.4453
# Epoch 42/50
# 3/3 [==============================] - 0s 28ms/step - loss: 33.5247 - val_loss: 30.9185
# Epoch 43/50
# 3/3 [==============================] - 0s 31ms/step - loss: 33.0380 - val_loss: 30.4120
# Epoch 44/50
# 3/3 [==============================] - 0s 28ms/step - loss: 32.6641 - val_loss: 29.9192
# Epoch 45/50
# 3/3 [==============================] - 0s 28ms/step - loss: 32.2249 - val_loss: 29.5469
# Epoch 46/50
# 3/3 [==============================] - 0s 27ms/step - loss: 31.9372 - val_loss: 29.1936
# Epoch 47/50
# 3/3 [==============================] - 0s 27ms/step - loss: 31.5216 - val_loss: 28.8930
# Epoch 48/50
# 3/3 [==============================] - 0s 27ms/step - loss: 31.2101 - val_loss: 28.6391
# Epoch 49/50
# 3/3 [==============================] - 0s 27ms/step - loss: 31.0143 - val_loss: 28.3419
# Epoch 50/50
# 3/3 [==============================] - 0s 28ms/step - loss: 30.7528 - val_loss: 28.0792

# %% [markdown]
# # Red Neuronal Multicapa

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               3328
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 69,377
# Trainable params: 69,377
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train,
          validation_data = (X_val, Y_val),
          epochs=50, 
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    8.522, max:  311.911, cur:   13.884)
# 	validation       	 (min:   12.123, max:  488.474, cur:   57.345)
# 10/10 [==============================] - 0s 23ms/step - loss: 13.8836 - val_loss: 57.3446
